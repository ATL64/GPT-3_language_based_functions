# %% [markdown]
# # Case Study - Validation questions

# %% [markdown]
# The goal of this notebook is to develop and understand the accuracy of a function to validate the equivalence of two sentences with respect to a question.  This means the function takes as input two strings, and then outputs GPT-3's "Yes" or "No" answer to the question of whether these two sentences say the same thing.
#
# I wanted this function as part of a utils package for developing further cognitive architectures powered by GPT-3.

# %% [markdown]
# 1. Imports and functions
# 2. Simple attempt
# 3. Chain of Thought attempt
# 4. Temp search with CoT
# 5. Conclusion

# %% [markdown]
# ## 1. Imports and functions

# %%
import re
import os
import openai
from time import time, sleep
import textwrap
import pandas as pd

# %%
def open_file(filepath):
    with open(filepath, 'r', encoding='utf-8') as infile:
        return infile.read()


def save_file(filepath, content):
    with open(filepath, 'w', encoding='utf-8') as outfile:
        outfile.write(content)

# change path to where you store your credentials
openai.api_key = open_file('../creds/creds.txt')


def gpt3_completion(prompt, label='gpt3', engine='text-davinci-002', temp=0.5, top_p=1.0, tokens=400, freq_pen=2.0, pres_pen=2.0, stop=['asdfasdf', 'asdasdf']):
    max_retry = 5
    retry = 0
    prompt = prompt.encode(encoding='ASCII', errors='ignore').decode()  # force it to fix any unicode errors
    while True:
        try:
            response = openai.Completion.create(
                engine=engine,
                prompt=prompt,
                temperature=temp,
                max_tokens=tokens,
                top_p=top_p,
                frequency_penalty=freq_pen,
                presence_penalty=pres_pen,
                stop=stop)
            text = response['choices'][0]['text'].strip()
            text = re.sub('\s+', ' ', text)
            return text
        except Exception as oops:
            retry += 1
            if retry >= max_retry:
                return "GPT3 error: %s" % oops
            print('Error communicating with OpenAI:', oops)
            sleep(1)

# %%
df_questions = pd.read_csv('validation_questions.csv')

# %% [markdown]
# ## 2. Simple attempt

# %%
df_questions

# %%
df_questions['gpt_answer'] = ''

# %% [markdown]
# We'll use the following template first:

# %% [markdown]
# In the following text we have a question and two answers.  Are the two answers the same? Answer with "Yes" or "No"
#
# QUESTION:
#
# question_from_dataframe
#
# ANSWERS:
#
# -first_answer_from_df
#
# -second_answer_from_df
#
# Are they the same answer? YES OR NO:

# %%
prompt_beginning = """In the following text we have a question and two answers.  Are the two answers the same? Answer with "Yes" or "No" """            
nl_str = """\n\n"""
question_str = """QUESTION:\n"""
answers_str = """ANSWERS: \n"""
final_answer_str = """Are they the same answer? YES OR NO:"""

# %% [markdown]
# Now let's iterate and call GPT-3 to populate the answers

# %%
gpt_answer_list = []
for row in df_questions.iterrows():
    question = row[1]['question']
    answer_1 = row[1]['answer_1']
    answer_2 = row[1]['answer_2']
    prompt = prompt_beginning + nl_str + question_str + question + nl_str + answers_str + "-" + answer_1 + "\n" + "-" + answer_2 + nl_str + final_answer_str
    final_answer = gpt3_completion(prompt)
    gpt_answer_list.append(final_answer)

# %%
df_questions['gpt_answer'] = gpt_answer_list

# %% [markdown]
# Let's see what GPT-3 got wrong

# %%
df_questions[df_questions['validation']!=df_questions['gpt_answer']]
# Out:
#     question_number                             question  \
# 7                 8               Why is the leaf green?
# 13               14  What do birds have that mice don't?
#
#                       answer_1                       answer_2 validation  \
# 7   Because of the Chlorophyll  Because of the carbon dioxide         No
# 13                       Wings  Birds have peaks, mice do not         No
#
#    gpt_answer
# 7         Yes
# 13        Yes

# %% [markdown]
# So we got 18 out of 20 questions right. Not bad, but not great either.

# %% [markdown]
# ## 3. Chain of Thought attempt

# %% [markdown]
# We know that CoT works pretty well (see https://arxiv.org/pdf/2201.11903.pdf)
# These papers talk mostly about mathematical reasoning.  Let's give it a shot for this equivalence validator function we are trying to build. To do this we change the final_answer_str.

# %% [markdown]
# In the following text we have a question and two answers.  Are the two answers the same? Answer with "Yes" or "No"
#
# QUESTION:
#
# question_from_dataframe
#
# ANSWERS:
#
# -first_answer_from_df
#
# -second_answer_from_df
#
# Are they the same answer? Use step by step reasoning and then output only a "Yes" or "No" answer:

# %%
final_answer_cot = """Are they the same answer? Use step by step reasoning and then output only a "Yes" or "No" answer:"""

# %%
gpt_cot_list = []
for row in df_questions.iterrows():
        question = row[1]['question']
        answer_1 = row[1]['answer_1']
        answer_2 = row[1]['answer_2']
        prompt = prompt_beginning + nl_str + question_str + question + nl_str + answers_str + "-" + answer_1 + "\n" + "-" + answer_2 + nl_str + final_answer_cot
        #print(prompt)
        final_answer = gpt3_completion(prompt)
        print(final_answer)
        gpt_cot_list.append(final_answer)
        print(row[0])

# %% [markdown]
# Let's condense the answers into yes or no

# %%
new_cot_list = []
for a in gpt_cot_list:
    if a not in ['Yes','No']:
        prompt_init = """Condense the following sentence into a simple "Yes" or "No" answer"""
        prompt = prompt_init + nl_str + a + nl_str + """ "Yes" or "No" output: """
        final_a = gpt3_completion(prompt)
        final_a.replace('.','').replace(' ','')
        new_cot_list.append(final_a)
    else:
        new_cot_list.append(a)

# %%
df_questions['gpt_cot'] = new_cot_list

# %%
df_questions
# Out:
#     question_number                                    question  \
# 0                 1              What is the hamburger made of?
# 1                 2              What is the hamburger made of?
# 2                 3                Will the stock market go up?
# 3                 4                Will the stock market go up?
# 4                 5              When did she fly the airplane?
# 5                 6              When did she fly the airplane?
# 6                 7                      Why is the leaf green?
# 7                 8                      Why is the leaf green?
# 8                 9                  Where are rainbows formed?
# 9                10                  Where are rainbows formed?
# 10               11                 How are presidents elected?
# 11               12                 How are presidents elected?
# 12               13         What do birds have that mice don't?
# 13               14         What do birds have that mice don't?
# 14               15            Why are northern countries cold?
# 15               16            Why are northern countries cold?
# 16               17              Where are computer chips made?
# 17               18              Where are computer chips made?
# 18               19  What do germans and french have in common?
# 19               20  What do germans and french have in common?
#
#                                        answer_1  \
# 0                 The hamburger is made of meat
# 1                 The hamburger is made of meat
# 2                      It will go on a bull run
# 3                      It will go on a bull run
# 4              She flew the airplane on Tuesday
# 5                                     At midday
# 6                    Because of the Chlorophyll
# 7                    Because of the Chlorophyll
# 8         Rainbows are formed in the atmosphere
# 9                                    In the sky
# 10    They are elected via democratic elections
# 11    They are elected via democratic elections
# 12                                        Wings
# 13                                        Wings
# 14  Because of the position relative to the Sun
# 15  Because of the position relative to the Sun
# 16                                     In China
# 17                                     In India
# 18                 They both are fans of cheese
# 19                       They like martial arts
#
#                                            answer_2 validation gpt_answer  \
# 0                                 It's made of meat        Yes        Yes
# 1                           It's made of vegetables         No         No
# 2                                     It will go up        Yes        Yes
# 3                               It will go sideways         No         No
# 4                                        On Tuesday        Yes        Yes
# 5                                       At midnight         No         No
# 6                Chlorophyll makes the plants green        Yes        Yes
# 7                     Because of the carbon dioxide         No        Yes
# 8                                        In the sky        Yes        Yes
# 9                                In our imagination         No         No
# 10              People vote to choose the president        Yes        Yes
# 11  There is a raffle and whoever wins is president         No         No
# 12                    Birds have wings, mice do not        Yes        Yes
# 13                    Birds have peaks, mice do not         No        Yes
# 14                          Due to the Sun position        Yes        Yes
# 15                         Due to the northern Gods         No         No
# 16                             In a region of China        Yes        Yes
# 17                                      In Pakistan         No         No
# 18                            They both like cheese        Yes        Yes
# 19                             They both like frogs         No         No
#
#    gpt_cot
# 0      Yes
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# 5       No
# 6      Yes
# 7       No
# 8      Yes
# 9       No
# 10     Yes
# 11      No
# 12     Yes
# 13     No.
# 14     Yes
# 15      No
# 16     Yes
# 17      No
# 18     Yes
# 19      No

# %% [markdown]
# ## 4. Temp search with CoT

# %% [markdown]
# Let's try out the CoT strategy using different temperatures

# %%
temp_list = [0.2, 0.4, 0.6, 0.8, 0.9, 0.95, 1]

# %%
score_list = []
for temp in temp_list:
    gpt_cot_list = []
    print(temp)
    for row in df_questions.iterrows():
        question = row[1]['question']
        answer_1 = row[1]['answer_1']
        answer_2 = row[1]['answer_2']
        prompt = prompt_beginning + nl_str + question_str + question + nl_str + answers_str + "-" + answer_1 + "\n" + "-" + answer_2 + nl_str + final_answer_cot
        #print(prompt)
        final_answer = gpt3_completion(prompt, temp = temp)
        #print(final_answer)
        if final_answer not in ['Yes','No']:
            prompt_init = """Condense the following sentence into a simple "Yes" or "No" answer"""
            prompt = prompt_init + nl_str + a + nl_str + """ "Yes" or "No" output: """
            final_a = gpt3_completion(prompt)
            final_a.replace('.','').replace(' ','')
            final_answer = final_a
        print(row[0])
        gpt_cot_list.append(final_answer)
    col_string = 'CoT_'+str(temp)
    df_questions[col_string] = gpt_cot_list
    score = sum(gpt_cot_list == df_questions['validation'])/20
    score_list.append(score)

# %% [markdown]
# I ran it twice, and got the two accuracy tables below:

# %%
df_results = pd.DataFrame(list(zip(temp_list, score_list)), columns =['Temp', 'Score'])

# %%
df_results
# Out:
#    Temp  Score
# 0  0.20   1.00
# 1  0.40   1.00
# 2  0.60   0.90
# 3  0.80   0.85
# 4  0.90   0.75
# 5  0.95   0.80
# 6  1.00   0.70

# %%
#df_results = pd.DataFrame(list(zip(temp_list, score_list)), columns =['Temp', 'Score'])

# %%
#df_results

# %% [markdown]
# So, less temperature is better.. Let's inspect the questions dataframe for the second run:

# %%
df_questions
# Out:
#     question_number                                    question  \
# 0                 1              What is the hamburger made of?
# 1                 2              What is the hamburger made of?
# 2                 3                Will the stock market go up?
# 3                 4                Will the stock market go up?
# 4                 5              When did she fly the airplane?
# 5                 6              When did she fly the airplane?
# 6                 7                      Why is the leaf green?
# 7                 8                      Why is the leaf green?
# 8                 9                  Where are rainbows formed?
# 9                10                  Where are rainbows formed?
# 10               11                 How are presidents elected?
# 11               12                 How are presidents elected?
# 12               13         What do birds have that mice don't?
# 13               14         What do birds have that mice don't?
# 14               15            Why are northern countries cold?
# 15               16            Why are northern countries cold?
# 16               17              Where are computer chips made?
# 17               18              Where are computer chips made?
# 18               19  What do germans and french have in common?
# 19               20  What do germans and french have in common?
#
#                                        answer_1  \
# 0                 The hamburger is made of meat
# 1                 The hamburger is made of meat
# 2                      It will go on a bull run
# 3                      It will go on a bull run
# 4              She flew the airplane on Tuesday
# 5                                     At midday
# 6                    Because of the Chlorophyll
# 7                    Because of the Chlorophyll
# 8         Rainbows are formed in the atmosphere
# 9                                    In the sky
# 10    They are elected via democratic elections
# 11    They are elected via democratic elections
# 12                                        Wings
# 13                                        Wings
# 14  Because of the position relative to the Sun
# 15  Because of the position relative to the Sun
# 16                                     In China
# 17                                     In India
# 18                 They both are fans of cheese
# 19                       They like martial arts
#
#                                            answer_2 validation gpt_answer  \
# 0                                 It's made of meat        Yes        Yes
# 1                           It's made of vegetables         No         No
# 2                                     It will go up        Yes        Yes
# 3                               It will go sideways         No         No
# 4                                        On Tuesday        Yes        Yes
# 5                                       At midnight         No         No
# 6                Chlorophyll makes the plants green        Yes        Yes
# 7                     Because of the carbon dioxide         No        Yes
# 8                                        In the sky        Yes        Yes
# 9                                In our imagination         No         No
# 10              People vote to choose the president        Yes        Yes
# 11  There is a raffle and whoever wins is president         No         No
# 12                    Birds have wings, mice do not        Yes        Yes
# 13                    Birds have peaks, mice do not         No        Yes
# 14                          Due to the Sun position        Yes        Yes
# 15                         Due to the northern Gods         No         No
# 16                             In a region of China        Yes        Yes
# 17                                      In Pakistan         No         No
# 18                            They both like cheese        Yes        Yes
# 19                             They both like frogs         No         No
#
#    gpt_cot CoT_0.2 CoT_0.4 CoT_0.6 CoT_0.8 CoT_0.9 CoT_0.95 CoT_1
# 0      Yes     Yes     Yes     Yes     Yes     Yes      Yes   Yes
# 1       No      No      No      No      No      No       No    No
# 2      Yes     Yes     Yes     Yes     Yes      No      Yes   Yes
# 3       No      No      No      No      No      No       No    No
# 4      Yes     Yes     Yes     Yes      No     Yes       No    No
# 5       No      No      No      No      No      No       No    No
# 6      Yes     Yes     Yes      No     Yes     Yes      Yes    No
# 7       No      No      No      No      No      No       No    No
# 8      Yes     Yes     Yes     Yes      No      No      Yes    No
# 9       No      No      No      No      No      No       No    No
# 10     Yes     Yes     Yes     Yes      No     Yes       No   Yes
# 11      No      No      No      No      No      No       No    No
# 12     Yes     Yes     Yes     Yes     Yes      No      Yes    No
# 13     No.      No      No      No      No      No       No    No
# 14     Yes     Yes     Yes     Yes     Yes     Yes       No    No
# 15      No      No      No      No      No      No       No    No
# 16     Yes     Yes     Yes      No     Yes      No      Yes    No
# 17      No      No      No      No      No     Yes       No    No
# 18     Yes     Yes     Yes     Yes     Yes     Yes       No   Yes
# 19      No      No      No      No      No      No       No    No

# %% [markdown]
# ## 5. Explicit CoT

# %% [markdown]
# In this one, we ask it to be explicit in the output, then call the api again to make it a yes or no answer. So the template will be:

# %% [markdown]
# In the following text we have a question and two answers. Are the two answers the same?
#
# QUESTION:
#
# question_from_dataframe
#
# ANSWERS:
#
# -first_answer_from_df
#
# -second_answer_from_df
#
# Are they the same answer? Use step by step reasoning

# %%
prompt_beginning = """In the following text we have a question and two answers.  Are the two answers the same? """            
nl_str = """\n\n"""
question_str = """QUESTION:\n"""
answers_str = """ANSWERS: \n"""
final_answer_str = """Are they the same answer? Use step by step reasoning"""

# %%
score_list = []
for temp in temp_list:
    gpt_cot_list = []
    print(temp)
    for row in df_questions.iterrows():
        question = row[1]['question']
        answer_1 = row[1]['answer_1']
        answer_2 = row[1]['answer_2']
        prompt = prompt_beginning + nl_str + question_str + question + nl_str + answers_str + "-" + answer_1 + "\n" + "-" + answer_2 + nl_str + final_answer_cot
        #print(prompt)
        final_answer = gpt3_completion(prompt, temp = temp)
        #print(final_answer)
        if final_answer not in ['Yes','No']:
            prompt_init = """Condense the following sentence into a simple "Yes" or "No" answer"""
            prompt = prompt_init + nl_str + a + nl_str + """ "Yes" or "No" output: """
            final_a = gpt3_completion(prompt)
            final_a.replace('.','').replace(' ','')
            final_answer = final_a
        print(row[0])
        gpt_cot_list.append(final_answer)
        col_string = 'CoT_'+str(temp)
    df_questions[col_string] = gpt_cot_list
    score = sum(gpt_cot_list == df_questions['validation'])/20
    score_list.append(score)

# %%
df_results = pd.DataFrame(list(zip(temp_list, score_list)), columns =['Temp', 'Score'])
df_results
# Out:
#    Temp  Score
# 0  0.20   1.00
# 1  0.40   1.00
# 2  0.60   0.85
# 3  0.80   0.75
# 4  0.90   0.75
# 5  0.95   0.75
# 6  1.00   0.75

# %%
df_questions
# Out:
#     question_number                                    question  \
# 0                 1              What is the hamburger made of?
# 1                 2              What is the hamburger made of?
# 2                 3                Will the stock market go up?
# 3                 4                Will the stock market go up?
# 4                 5              When did she fly the airplane?
# 5                 6              When did she fly the airplane?
# 6                 7                      Why is the leaf green?
# 7                 8                      Why is the leaf green?
# 8                 9                  Where are rainbows formed?
# 9                10                  Where are rainbows formed?
# 10               11                 How are presidents elected?
# 11               12                 How are presidents elected?
# 12               13         What do birds have that mice don't?
# 13               14         What do birds have that mice don't?
# 14               15            Why are northern countries cold?
# 15               16            Why are northern countries cold?
# 16               17              Where are computer chips made?
# 17               18              Where are computer chips made?
# 18               19  What do germans and french have in common?
# 19               20  What do germans and french have in common?
#
#                                        answer_1  \
# 0                 The hamburger is made of meat
# 1                 The hamburger is made of meat
# 2                      It will go on a bull run
# 3                      It will go on a bull run
# 4              She flew the airplane on Tuesday
# 5                                     At midday
# 6                    Because of the Chlorophyll
# 7                    Because of the Chlorophyll
# 8         Rainbows are formed in the atmosphere
# 9                                    In the sky
# 10    They are elected via democratic elections
# 11    They are elected via democratic elections
# 12                                        Wings
# 13                                        Wings
# 14  Because of the position relative to the Sun
# 15  Because of the position relative to the Sun
# 16                                     In China
# 17                                     In India
# 18                 They both are fans of cheese
# 19                       They like martial arts
#
#                                            answer_2 validation gpt_answer  \
# 0                                 It's made of meat        Yes        Yes
# 1                           It's made of vegetables         No         No
# 2                                     It will go up        Yes        Yes
# 3                               It will go sideways         No         No
# 4                                        On Tuesday        Yes        Yes
# 5                                       At midnight         No         No
# 6                Chlorophyll makes the plants green        Yes        Yes
# 7                     Because of the carbon dioxide         No        Yes
# 8                                        In the sky        Yes        Yes
# 9                                In our imagination         No         No
# 10              People vote to choose the president        Yes        Yes
# 11  There is a raffle and whoever wins is president         No         No
# 12                    Birds have wings, mice do not        Yes        Yes
# 13                    Birds have peaks, mice do not         No        Yes
# 14                          Due to the Sun position        Yes        Yes
# 15                         Due to the northern Gods         No         No
# 16                             In a region of China        Yes        Yes
# 17                                      In Pakistan         No         No
# 18                            They both like cheese        Yes        Yes
# 19                             They both like frogs         No         No
#
#    gpt_cot CoT_0.2 CoT_0.4 CoT_0.6 CoT_0.8 CoT_0.9 CoT_0.95 CoT_1
# 0      Yes     Yes     Yes     Yes      No      No       No   Yes
# 1       No      No      No      No      No      No       No    No
# 2      Yes     Yes     Yes     Yes      No      No      Yes   Yes
# 3       No      No      No      No      No      No       No   Yes
# 4      Yes     Yes     Yes     Yes     Yes     Yes      Yes    No
# 5       No      No      No      No      No      No       No    No
# 6      Yes     Yes     Yes      No     Yes     Yes       No    No
# 7       No      No      No      No      No      No       No    No
# 8      Yes     Yes     Yes      No      No     Yes       No    No
# 9       No      No      No      No      No      No       No    No
# 10     Yes     Yes     Yes     Yes     Yes      No      Yes   Yes
# 11      No      No      No      No      No      No       No    No
# 12     Yes     Yes     Yes     Yes      No     Yes       No   Yes
# 13     No.      No      No      No      No      No       No    No
# 14     Yes     Yes     Yes      No     Yes      No      Yes   Yes
# 15      No      No      No      No      No      No       No    No
# 16     Yes     Yes     Yes     Yes     Yes      No       No   Yes
# 17      No      No      No      No      No      No       No    No
# 18     Yes     Yes     Yes     Yes      No     Yes      Yes    No
# 19      No      No      No      No      No      No       No    No

# %% [markdown]
# ## 5. Conclusion

# %% [markdown]
# As we see in the results above, lower temperatures behave better.  So we can define a function with temperature at around 0.3, and we should be doing fine.
